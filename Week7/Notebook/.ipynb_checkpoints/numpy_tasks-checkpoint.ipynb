# %%
import numpy as np
a1 = np.arange(1, 11)
a1
a2 = np.random.randint(1, 10, size=(3, 3))
a2
print("Sum:", a1.sum())
print("Mean:", a1.mean())
print("Max:", a1.max())
a_multiplied = a1 * 2
a_multiplied
a_replaced = a1.copy()
a_replaced[a_replaced > 5] = 0
a_replaced
# Out:
# Sum: 55
# Mean: 5.5
# Max: 10
# array([1, 2, 3, 4, 5, 0, 0, 0, 0, 0])
