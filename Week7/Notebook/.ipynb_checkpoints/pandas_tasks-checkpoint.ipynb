# %%
import pandas as pd

data = {
    "Name": ["Ali", "Aruzhan", "Daniyar", "Amina", "Timur"],
    "Age": [19, 21, 20, 22, 18],
    "Score": [85, 90, 78, 92, 88]
}

df = pd.DataFrame(data)
df

df.head(3)

df.describe()

df["Score"].mean()

df[df["Age"] > 20]

df[df["Score"] > 80]
# Out:
#       Name  Age  Score
# 0      Ali   19     85
# 1  Aruzhan   21     90
# 3    Amina   22     92
# 4    Timur   18     88
